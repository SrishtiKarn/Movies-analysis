# %%
import numpy as np
import pandas as pd

# %%
movie=pd.read_csv('BollywoodMovieDetail.csv')

# %%
movie.head()
# Out:
#       imdbId                              title  releaseYear  releaseDate  \
# 0  tt0118578                             Albela         2001  20 Apr 2001
# 1  tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2  tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3  tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4  tt0227194                         One 2 Ka 4         2001  30 Mar 2001
#
#                          genre  \
# 0                      Romance
# 1  Adventure | Drama | Musical
# 2              Action | Comedy
# 3              Drama | Romance
# 4      Action | Comedy | Drama
#
#                                              writers  \
# 0  Honey Irani (screenplay) | Honey Irani (story)...
# 1  Ashutosh Gowariker (story) | Ashutosh Gowarike...
# 2                                                NaN
# 3  K.S. Adiyaman | Arun Kumar (assistant dialogue...
# 4  Sanjay Chhel | Raaj Kumar Dahima (screenplay) ...
#
# ...

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1284 entries, 0 to 1283
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   imdbId       1284 non-null   object
#  1   title        1284 non-null   object
#  2   releaseYear  1284 non-null   int64
#  3   releaseDate  1231 non-null   object
#  4   genre        1282 non-null   object
#  5   writers      1165 non-null   object
#  6   actors       1281 non-null   object
#  7   directors    1280 non-null   object
#  8   sequel       1281 non-null   float64
#  9   hitFlop      1284 non-null   int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 100.4+ KB

# %%
type(movie.dtypes)
# Out:
# pandas.core.series.Series

# %%
movie.describe()
# Out:
#        releaseYear       sequel      hitFlop
# count  1284.000000  1281.000000  1284.000000
# mean   2007.989097     0.035129     2.144081
# std       4.005243     0.188371     1.812820
# min    2001.000000     0.000000     1.000000
# 25%    2004.000000     0.000000     1.000000
# 50%    2008.000000     0.000000     1.000000
# 75%    2011.000000     0.000000     2.000000
# max    2014.000000     2.000000     9.000000

# %%
movie.corr()
# Out:
#              releaseYear    sequel   hitFlop
# releaseYear     1.000000  0.132172  0.009878
# sequel          0.132172  1.000000  0.251237
# hitFlop         0.009878  0.251237  1.000000

# %%
movie.tail()
# Out:
#          imdbId                 title  releaseYear  releaseDate     genre  \
# 1279  tt4121522  Shuruaat Ka Interval         2014  15 Aug 2014       NaN
# 1280  tt4187650      Trip to Bhangarh         2014  28 Aug 2014    Horror
# 1281  tt4190220              Zed Plus         2014  28 Nov 2014       NaN
# 1282  tt4219300       Gollu aur Pappu         2014  21 Nov 2014    Comedy
# 1283  tt4228746                   Zid         2014  28 Nov 2014  Thriller
#
#                                                 writers  \
# 1279  Aarti S. Bagdi | Amrit Raj Gupta | Krishan Hoo...
# 1280                                                NaN
# 1281  Chandra Prakash Dwivedi (screen play and dialo...
# 1282                                                NaN
# 1283                   Vivek Agnihotri | Rohit Malhotra
#
#                                                  actors  \
# 1279  Kaivalya Chheda | Rajsekhar Aningi | Avidant B...
# 1280  Manish Choudhary | Suzanna Mukherjee | Poonam ...
# ...

# %%
movie['title']
# Out:
# 0                                  Albela
# 1       Lagaan: Once Upon a Time in India
# 2                Meri Biwi Ka Jawab Nahin
# 3                  Hum Tumhare Hain Sanam
# 4                              One 2 Ka 4
#                       ...
# 1279                 Shuruaat Ka Interval
# 1280                     Trip to Bhangarh
# 1281                             Zed Plus
# 1282                      Gollu aur Pappu
# 1283                                  Zid
# Name: title, Length: 1284, dtype: object

# %%
movie['title'].shape
# Out:
# (1284,)

# %%
movie[['title','sequel','hitFlop']]
# Out:
#                                   title  sequel  hitFlop
# 0                                Albela     0.0        2
# 1     Lagaan: Once Upon a Time in India     0.0        6
# 2              Meri Biwi Ka Jawab Nahin     0.0        1
# 3                Hum Tumhare Hain Sanam     0.0        4
# 4                            One 2 Ka 4     0.0        1
# ...                                 ...     ...      ...
# 1279               Shuruaat Ka Interval     0.0        1
# 1280                   Trip to Bhangarh     0.0        1
# 1281                           Zed Plus     0.0        1
# 1282                    Gollu aur Pappu     0.0        1
# 1283                                Zid     0.0        2
#
# [1284 rows x 3 columns]

# %%
movie['hitFlop']>8
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1279    False
# 1280    False
# 1281    False
# 1282    False
# 1283    False
# Name: hitFlop, Length: 1284, dtype: bool

# %%
movie[movie['hitFlop']>8].shape
# Out:
# (4, 10)

# %%
movie.tail(2)
# Out:
#          imdbId            title  releaseYear  releaseDate     genre  \
# 1282  tt4219300  Gollu aur Pappu         2014  21 Nov 2014    Comedy
# 1283  tt4228746              Zid         2014  28 Nov 2014  Thriller
#
#                                writers  \
# 1282                               NaN
# 1283  Vivek Agnihotri | Rohit Malhotra
#
#                                                  actors  \
# 1282  Vir Das | Sandeepa Dhar | Rahul Handa | Dimple...
# 1283  Shradha Das | Mohan Kapoor | Mannara | Karanvi...
#
#                            directors  sequel  hitFlop
# 1282                  Kabir Sadanand     0.0        1
# 1283  Rohit Malhotra | Anubhav Sinha     0.0        2

# %%
movie.columns
# Out:
# Index(['imdbId', 'title', 'releaseYear', 'releaseDate', 'genre', 'writers',
#        'actors', 'directors', 'sequel', 'hitFlop'],
#       dtype='object')

# %%
mask1=movie['releaseYear']>2005

# %%
mask2=movie['genre']=='Romance'

# %%
mask3=movie['hitFlop']>5

# %%
movie['hitFlop']*10
# Out:
# 0       20
# 1       60
# 2       10
# 3       40
# 4       10
#         ..
# 1279    10
# 1280    10
# 1281    10
# 1282    10
# 1283    20
# Name: hitFlop, Length: 1284, dtype: int64

# %%
movie['critics_rating']=movie['hitFlop']-2

# %%
movie.shape
# Out:
# (1284, 11)

# %%
movie.head()
# Out:
#       imdbId                              title  releaseYear  releaseDate  \
# 0  tt0118578                             Albela         2001  20 Apr 2001
# 1  tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2  tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3  tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4  tt0227194                         One 2 Ka 4         2001  30 Mar 2001
#
#                          genre  \
# 0                      Romance
# 1  Adventure | Drama | Musical
# 2              Action | Comedy
# 3              Drama | Romance
# 4      Action | Comedy | Drama
#
#                                              writers  \
# 0  Honey Irani (screenplay) | Honey Irani (story)...
# 1  Ashutosh Gowariker (story) | Ashutosh Gowarike...
# 2                                                NaN
# 3  K.S. Adiyaman | Arun Kumar (assistant dialogue...
# 4  Sanjay Chhel | Raaj Kumar Dahima (screenplay) ...
#
# ...

# %%
movie.iloc[5:11,:]
# Out:
#        imdbId                        title  releaseYear  releaseDate  \
# 5   tt0238936                       Devdas         2002  12 Jul 2002
# 6   tt0247911  Aap Mujhe Achche Lagne Lage         2002  19 Apr 2002
# 7   tt0248126  Kabhi Khushi Kabhie Gham...         2001  14 Dec 2001
# 8   tt0248216          Na Tum Jaano Na Hum         2002  10 May 2002
# 9   tt0248617                   Yaadein...         2001  27 Jun 2001
# 10  tt0255713                     Zubeidaa         2001  19 Jan 2001
#
#                             genre  \
# 5               Musical | Romance
# 6        Action | Drama | Romance
# 7       Drama | Musical | Romance
# 8        Comedy | Drama | Musical
# 9       Musical | Drama | Romance
# 10  Adventure | Biography | Drama
#
#                                               writers  \
# 5   Saratchandra Chatterjee (based on the novel by...
# 6   Robin Bhatt (story) | Girish Dhamija (dialogue...
# 7            Karan Johar | Sheena Parikh (screenplay)
# ...

# %%
movie.iloc[6:11,1:5]
# Out:
#                           title  releaseYear  releaseDate  \
# 6   Aap Mujhe Achche Lagne Lage         2002  19 Apr 2002
# 7   Kabhi Khushi Kabhie Gham...         2001  14 Dec 2001
# 8           Na Tum Jaano Na Hum         2002  10 May 2002
# 9                    Yaadein...         2001  27 Jun 2001
# 10                     Zubeidaa         2001  19 Jan 2001
#
#                             genre
# 6        Action | Drama | Romance
# 7       Drama | Musical | Romance
# 8        Comedy | Drama | Musical
# 9       Musical | Drama | Romance
# 10  Adventure | Biography | Drama

# %%
movie.iloc[7,:]
# Out:
# imdbId                                                    tt0248126
# title                                   Kabhi Khushi Kabhie Gham...
# releaseYear                                                    2001
# releaseDate                                             14 Dec 2001
# genre                                     Drama | Musical | Romance
# writers                    Karan Johar | Sheena Parikh (screenplay)
# actors            Amitabh Bachchan | Jaya Bhaduri | Shah Rukh Kh...
# directors                                               Karan Johar
# sequel                                                            0
# hitFlop                                                           8
# critics_rating                                                    6
# Name: 7, dtype: object

# %%
movie.shape
# Out:
# (1284, 11)

# %%
movie.values[5]
# Out:
# array(['tt0238936', 'Devdas', 2002, '12 Jul 2002', 'Musical | Romance',
#        'Saratchandra Chatterjee (based on the novel by) | Prakash Kapadia (screenplay) | Sanjay Leela Bhansali (screenplay) | Prakash Kapadia (dialogue)',
#        'Shah Rukh Khan | Madhuri Dixit | Aishwarya Rai Bachchan | Jackie Shroff',
#        'Sanjay Leela Bhansali', 0.0, 6, 4], dtype=object)

# %%
movie.iloc[:,1]
# Out:
# 0                                  Albela
# 1       Lagaan: Once Upon a Time in India
# 2                Meri Biwi Ka Jawab Nahin
# 3                  Hum Tumhare Hain Sanam
# 4                              One 2 Ka 4
#                       ...
# 1279                 Shuruaat Ka Interval
# 1280                     Trip to Bhangarh
# 1281                             Zed Plus
# 1282                      Gollu aur Pappu
# 1283                                  Zid
# Name: title, Length: 1284, dtype: object

# %%
movie.sort_values('hitFlop')
# Out:
#          imdbId                    title  releaseYear  releaseDate  \
# 641   tt1214948       Bhram: An Illusion         2008  04 Apr 2008
# 523   tt0898943                   Raqeeb         2007  18 May 2007
# 524   tt0920464  Manorama Six Feet Under         2007  21 Sep 2007
# 525   tt0926029                  99.9 FM         2005          NaN
# 526   tt0926187              Arjun Devaa         2001          NaN
# ...         ...                      ...          ...          ...
# 617   tt1182937      Rab Ne Bana Di Jodi         2008  12 Dec 2008
# 625   tt1187043                 3 Idiots         2009  25 Dec 2009
# 32    tt0284137     Gadar: Ek Prem Katha         2001  15 Jun 2001
# 1092  tt2338151                       PK         2014  19 Dec 2014
# 901   tt1833673                 Dhoom: 3         2013  20 Dec 2013
#
#                           genre  \
# 641   Drama | Mystery | Romance
# 523     Crime | Drama | Mystery
# 524     Crime | Drama | Mystery
# ...

# %%
movie.sort_values('hitFlop',ascending=False,inplace=True)

# %%
movie.head()
# Out:
#          imdbId                 title  releaseYear  releaseDate  \
# 1092  tt2338151                    PK         2014  19 Dec 2014
# 901   tt1833673              Dhoom: 3         2013  20 Dec 2013
# 32    tt0284137  Gadar: Ek Prem Katha         2001  15 Jun 2001
# 625   tt1187043              3 Idiots         2009  25 Dec 2009
# 1113  tt2372222                  Kick         2014  25 Jul 2014
#
#                           genre  \
# 1092   Comedy | Drama | Fantasy
# 901   Action | Crime | Thriller
# 32     Action | Drama | Romance
# 625              Comedy | Drama
# 1113  Action | Comedy | Romance
#
#                                                 writers  \
# 1092  Rajkumar Hirani | Abhijit Joshi | Sreerag Nambiar
# 901   Vijay Krishna Acharya (story) | Aditya Chopra ...
# 32                                    Shaktimaan Talwar
# 625   Rajkumar Hirani | Abhijit Joshi | Vidhu Vinod ...
# 1113  Vakkantham Vamsi (story) | Rajat Arora (screen...
#
# ...

# %%
movie.sort_values(['releaseYear','title'])
# Out:
#          imdbId                             title  releaseYear  releaseDate  \
# 58    tt0305173  Aamdani Atthanni Kharcha Rupaiya         2001  21 Dec 2001
# 21    tt0273406                            Aashiq         2001  26 Jan 2001
# 26    tt0278291                           Ajnabee         2001  21 Sep 2001
# 37    tt0289845                               Aks         2001  13 Jul 2001
# 0     tt0118578                            Albela         2001  20 Apr 2001
# ...         ...                               ...          ...          ...
# 1229  tt3382148                          Yaariyan         2014  10 Jan 2014
# 1244  tt3524410                  Yeh Hai Bakrapur         2014  09 May 2014
# 1243  tt3514330                       Youngistaan         2014  28 Mar 2014
# 1281  tt4190220                          Zed Plus         2014  28 Nov 2014
# 1283  tt4228746                               Zid         2014  28 Nov 2014
#
#                            genre  \
# ...

# %%
movie.sort_values(['releaseYear','title'],ascending=[False,True])
# Out:
#          imdbId                          title  releaseYear  releaseDate  \
# 1114  tt2372678                       2 States         2014  18 Apr 2014
# 1266  tt3720634  3 AM: A Paranormal Experience         2014  26 Sep 2014
# 253   tt0403935                 Action Jackson         2014  05 Dec 2014
# 1270  tt3822600             Amit Sahni Ki List         2014  18 Jul 2014
# 1254  tt3617048                Angry Young Man         2014  11 Apr 2014
# ...         ...                            ...          ...          ...
# 42    tt0292740       Yeh Raaste Hain Pyaar Ke         2001  10 Aug 2001
# 49    tt0298606  Yeh Teraa Ghar Yeh Meraa Ghar         2001  12 Oct 2001
# 50    tt0298607           Yeh Zindagi Ka Safar         2001  16 Nov 2001
# 607   tt1176141                       Zahreela         2001  05 Mar 2001
# 10    tt0255713                       Zubeidaa         2001  19 Jan 2001
#
#                               genre  \
# 1114                Drama | Romance
# ...

# %%
movie['title'].is_unique
# Out:
# True

# %%
movie['hitFlop'].is_unique
# Out:
# False

# %%
movie.head()
# Out:
#          imdbId                 title  releaseYear  releaseDate  \
# 1092  tt2338151                    PK         2014  19 Dec 2014
# 901   tt1833673              Dhoom: 3         2013  20 Dec 2013
# 32    tt0284137  Gadar: Ek Prem Katha         2001  15 Jun 2001
# 625   tt1187043              3 Idiots         2009  25 Dec 2009
# 1113  tt2372222                  Kick         2014  25 Jul 2014
#
#                           genre  \
# 1092   Comedy | Drama | Fantasy
# 901   Action | Crime | Thriller
# 32     Action | Drama | Romance
# 625              Comedy | Drama
# 1113  Action | Comedy | Romance
#
#                                                 writers  \
# 1092  Rajkumar Hirani | Abhijit Joshi | Sreerag Nambiar
# 901   Vijay Krishna Acharya (story) | Aditya Chopra ...
# 32                                    Shaktimaan Talwar
# 625   Rajkumar Hirani | Abhijit Joshi | Vidhu Vinod ...
# 1113  Vakkantham Vamsi (story) | Rajat Arora (screen...
#
# ...

# %%
movie.set_index('title')
# Out:
#                          imdbId  releaseYear  releaseDate  \
# title
# PK                    tt2338151         2014  19 Dec 2014
# Dhoom: 3              tt1833673         2013  20 Dec 2013
# Gadar: Ek Prem Katha  tt0284137         2001  15 Jun 2001
# 3 Idiots              tt1187043         2009  25 Dec 2009
# Kick                  tt2372222         2014  25 Jul 2014
# ...                         ...          ...          ...
# Bardaasht             tt0409724         2004  23 Apr 2004
# Guzaarish             tt1438298         2010  19 Nov 2010
# Chal Chala Chal       tt1438486         2009  06 Feb 2009
# Fast Forward          tt1442570         2009  25 Sep 2009
# 26th July at Barista  tt1216276         2008  14 Mar 2008
#
#                                           genre  \
# title
# PK                     Comedy | Drama | Fantasy
# Dhoom: 3              Action | Crime | Thriller
# Gadar: Ek Prem Katha   Action | Drama | Romance
# 3 Idiots                         Comedy | Drama
# ...

# %%
movie.set_index('title',inplace=True)

# %%
movie.sort_index(ascending=False)
# Out:
#                                 imdbId  releaseYear  releaseDate  \
# title
# Zubeidaa                     tt0255713         2001  19 Jan 2001
# Zor Lagaa Ke... Haiya!       tt1479857         2009  12 Jun 2009
# Zokkomon                     tt1605790         2011  22 Apr 2011
# Zindagi Tere Naam            tt2164702         2012  16 Mar 2012
# Zindagi Na Milegi Dobara     tt1562872         2011  15 Jul 2011
# ...                                ...          ...          ...
# 1920: Evil Returns           tt2222550         2012  02 Nov 2012
# 1920                         tt1301698         2008  12 Sep 2008
# 16 December                  tt0313844         2002  22 Mar 2002
# 13B: Fear Has a New Address  tt1385824         2009  06 Mar 2009
# ...Yahaan                    tt0473567         2005  29 Jul 2005
#
#                                                      genre  \
# title
# Zubeidaa                     Adventure | Biography | Drama
# ...

# %%
movie.reset_index()
# Out:
#                      title     imdbId  releaseYear  releaseDate  \
# 0                       PK  tt2338151         2014  19 Dec 2014
# 1                 Dhoom: 3  tt1833673         2013  20 Dec 2013
# 2     Gadar: Ek Prem Katha  tt0284137         2001  15 Jun 2001
# 3                 3 Idiots  tt1187043         2009  25 Dec 2009
# 4                     Kick  tt2372222         2014  25 Jul 2014
# ...                    ...        ...          ...          ...
# 1279             Bardaasht  tt0409724         2004  23 Apr 2004
# 1280             Guzaarish  tt1438298         2010  19 Nov 2010
# 1281       Chal Chala Chal  tt1438486         2009  06 Feb 2009
# 1282          Fast Forward  tt1442570         2009  25 Sep 2009
# 1283  26th July at Barista  tt1216276         2008  14 Mar 2008
#
#                           genre  \
# 0      Comedy | Drama | Fantasy
# 1     Action | Crime | Thriller
# 2      Action | Drama | Romance
# 3                Comedy | Drama
# ...

# %%
movie.rename(columns={'writers':'story','hitFlop':'rating'})
# Out:
#                          imdbId  releaseYear  releaseDate  \
# title
# PK                    tt2338151         2014  19 Dec 2014
# Dhoom: 3              tt1833673         2013  20 Dec 2013
# Gadar: Ek Prem Katha  tt0284137         2001  15 Jun 2001
# 3 Idiots              tt1187043         2009  25 Dec 2009
# Kick                  tt2372222         2014  25 Jul 2014
# ...                         ...          ...          ...
# Bardaasht             tt0409724         2004  23 Apr 2004
# Guzaarish             tt1438298         2010  19 Nov 2010
# Chal Chala Chal       tt1438486         2009  06 Feb 2009
# Fast Forward          tt1442570         2009  25 Sep 2009
# 26th July at Barista  tt1216276         2008  14 Mar 2008
#
#                                           genre  \
# title
# PK                     Comedy | Drama | Fantasy
# Dhoom: 3              Action | Crime | Thriller
# Gadar: Ek Prem Katha   Action | Drama | Romance
# 3 Idiots                         Comedy | Drama
# ...

# %%
movie.columns
# Out:
# Index(['imdbId', 'releaseYear', 'releaseDate', 'genre', 'writers', 'actors',
#        'directors', 'sequel', 'hitFlop', 'critics_rating'],
#       dtype='object')

# %%
movie.drop('releaseDate',axis=1)
# Out:
#                          imdbId  releaseYear                      genre  \
# title
# PK                    tt2338151         2014   Comedy | Drama | Fantasy
# Dhoom: 3              tt1833673         2013  Action | Crime | Thriller
# Gadar: Ek Prem Katha  tt0284137         2001   Action | Drama | Romance
# 3 Idiots              tt1187043         2009             Comedy | Drama
# Kick                  tt2372222         2014  Action | Comedy | Romance
# ...                         ...          ...                        ...
# Bardaasht             tt0409724         2004                      Drama
# Guzaarish             tt1438298         2010   Comedy | Drama | Romance
# Chal Chala Chal       tt1438486         2009    Action | Comedy | Crime
# Fast Forward          tt1442570         2009   Action | Drama | Musical
# 26th July at Barista  tt1216276         2008                      Drama
#
#                                                                 writers  \
# title
# ...

# %%
movie.drop('PK')
# Out:
#                          imdbId  releaseYear  releaseDate  \
# title
# Dhoom: 3              tt1833673         2013  20 Dec 2013
# Gadar: Ek Prem Katha  tt0284137         2001  15 Jun 2001
# 3 Idiots              tt1187043         2009  25 Dec 2009
# Kick                  tt2372222         2014  25 Jul 2014
# Dhoom:2               tt0441048         2006  24 Nov 2006
# ...                         ...          ...          ...
# Bardaasht             tt0409724         2004  23 Apr 2004
# Guzaarish             tt1438298         2010  19 Nov 2010
# Chal Chala Chal       tt1438486         2009  06 Feb 2009
# Fast Forward          tt1442570         2009  25 Sep 2009
# 26th July at Barista  tt1216276         2008  14 Mar 2008
#
#                                           genre  \
# title
# Dhoom: 3              Action | Crime | Thriller
# Gadar: Ek Prem Katha   Action | Drama | Romance
# 3 Idiots                         Comedy | Drama
# Kick                  Action | Comedy | Romance
# ...

# %%
movie.drop('Dhoom: 3')
# Out:
#                          imdbId  releaseYear  releaseDate  \
# title
# PK                    tt2338151         2014  19 Dec 2014
# Gadar: Ek Prem Katha  tt0284137         2001  15 Jun 2001
# 3 Idiots              tt1187043         2009  25 Dec 2009
# Kick                  tt2372222         2014  25 Jul 2014
# Dhoom:2               tt0441048         2006  24 Nov 2006
# ...                         ...          ...          ...
# Bardaasht             tt0409724         2004  23 Apr 2004
# Guzaarish             tt1438298         2010  19 Nov 2010
# Chal Chala Chal       tt1438486         2009  06 Feb 2009
# Fast Forward          tt1442570         2009  25 Sep 2009
# 26th July at Barista  tt1216276         2008  14 Mar 2008
#
#                                           genre  \
# title
# PK                     Comedy | Drama | Fantasy
# Gadar: Ek Prem Katha   Action | Drama | Romance
# 3 Idiots                         Comedy | Drama
# Kick                  Action | Comedy | Romance
# ...

# %%
def to_upper(text):
    text=str(text)
    return text.upper()

# %%
to_upper('hello')
# Out:
# 'HELLO'

# %%
movie['directors'].apply(to_upper)
# Out:
# title
# PK                            RAJKUMAR HIRANI
# Dhoom: 3                VIJAY KRISHNA ACHARYA
# Gadar: Ek Prem Katha              ANIL SHARMA
# 3 Idiots                      RAJKUMAR HIRANI
# Kick                         SAJID NADIADWALA
#                                 ...
# Bardaasht                       EESHWAR NIVAS
# Guzaarish               SANJAY LEELA BHANSALI
# Chal Chala Chal                  RAJEEV KUMAR
# Fast Forward                 ZAIGHAM ALI SYED
# 26th July at Barista             MOHAN SHARMA
# Name: directors, Length: 1284, dtype: object

# %%
movie['directors']=movie['directors'].apply(to_upper)

# %%
movie.head()
# Out:
#                          imdbId  releaseYear  releaseDate  \
# title
# PK                    tt2338151         2014  19 Dec 2014
# Dhoom: 3              tt1833673         2013  20 Dec 2013
# Gadar: Ek Prem Katha  tt0284137         2001  15 Jun 2001
# 3 Idiots              tt1187043         2009  25 Dec 2009
# Kick                  tt2372222         2014  25 Jul 2014
#
#                                           genre  \
# title
# PK                     Comedy | Drama | Fantasy
# Dhoom: 3              Action | Crime | Thriller
# Gadar: Ek Prem Katha   Action | Drama | Romance
# 3 Idiots                         Comedy | Drama
# Kick                  Action | Comedy | Romance
#
#                                                                 writers  \
# title
# PK                    Rajkumar Hirani | Abhijit Joshi | Sreerag Nambiar
# Dhoom: 3              Vijay Krishna Acharya (story) | Aditya Chopra ...
# Gadar: Ek Prem Katha                                  Shaktimaan Talwar
# ...

# %%
movie['writers'].count()
# Out:
# 1165

# %%
movie['sequel'].count()
# Out:
# 1281

# %%
movie.fillna({'writers':'Nowriters','sequel':0})
# Out:
#                          imdbId  releaseYear  releaseDate  \
# title
# PK                    tt2338151         2014  19 Dec 2014
# Dhoom: 3              tt1833673         2013  20 Dec 2013
# Gadar: Ek Prem Katha  tt0284137         2001  15 Jun 2001
# 3 Idiots              tt1187043         2009  25 Dec 2009
# Kick                  tt2372222         2014  25 Jul 2014
# ...                         ...          ...          ...
# Bardaasht             tt0409724         2004  23 Apr 2004
# Guzaarish             tt1438298         2010  19 Nov 2010
# Chal Chala Chal       tt1438486         2009  06 Feb 2009
# Fast Forward          tt1442570         2009  25 Sep 2009
# 26th July at Barista  tt1216276         2008  14 Mar 2008
#
#                                           genre  \
# title
# PK                     Comedy | Drama | Fantasy
# Dhoom: 3              Action | Crime | Thriller
# Gadar: Ek Prem Katha   Action | Drama | Romance
# 3 Idiots                         Comedy | Drama
# ...

# %%
movie.fillna({'writers':'Nowriters','sequel':0},inplace=True)

# %%
movie['writers'].count()
# Out:
# 1284

# %%
movie['sequel'].astype('int')
# Out:
# title
# PK                      0
# Dhoom: 3                1
# Gadar: Ek Prem Katha    0
# 3 Idiots                0
# Kick                    0
#                        ..
# Bardaasht               0
# Guzaarish               0
# Chal Chala Chal         0
# Fast Forward            0
# 26th July at Barista    0
# Name: sequel, Length: 1284, dtype: int32

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1284 entries, PK to 26th July at Barista
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   imdbId          1284 non-null   object
#  1   releaseYear     1284 non-null   int64
#  2   releaseDate     1231 non-null   object
#  3   genre           1282 non-null   object
#  4   writers         1284 non-null   object
#  5   actors          1281 non-null   object
#  6   directors       1284 non-null   object
#  7   sequel          1284 non-null   float64
#  8   hitFlop         1284 non-null   int64
#  9   critics_rating  1284 non-null   int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 150.3+ KB

# %%
movie['sequel']=movie['sequel'].astype('category')

# %%
movie['sequel']
# Out:
# title
# PK                      0.0
# Dhoom: 3                1.0
# Gadar: Ek Prem Katha    0.0
# 3 Idiots                0.0
# Kick                    0.0
#                        ...
# Bardaasht               0.0
# Guzaarish               0.0
# Chal Chala Chal         0.0
# Fast Forward            0.0
# 26th July at Barista    0.0
# Name: sequel, Length: 1284, dtype: category
# Categories (3, float64): [0.0, 1.0, 2.0]

# %%
movie.dropna(0)
# Out:
#                          imdbId  releaseYear  releaseDate  \
# title
# PK                    tt2338151         2014  19 Dec 2014
# Dhoom: 3              tt1833673         2013  20 Dec 2013
# Gadar: Ek Prem Katha  tt0284137         2001  15 Jun 2001
# 3 Idiots              tt1187043         2009  25 Dec 2009
# Kick                  tt2372222         2014  25 Jul 2014
# ...                         ...          ...          ...
# Bardaasht             tt0409724         2004  23 Apr 2004
# Guzaarish             tt1438298         2010  19 Nov 2010
# Chal Chala Chal       tt1438486         2009  06 Feb 2009
# Fast Forward          tt1442570         2009  25 Sep 2009
# 26th July at Barista  tt1216276         2008  14 Mar 2008
#
#                                           genre  \
# title
# PK                     Comedy | Drama | Fantasy
# Dhoom: 3              Action | Crime | Thriller
# Gadar: Ek Prem Katha   Action | Drama | Romance
# 3 Idiots                         Comedy | Drama
# ...

# %%
movie.dropna().shape
# Out:
# (1226, 10)

# %%
movie.dropna(how='all').shape
# Out:
# (1284, 10)

# %%
movie.dropna(subset=['releaseDate','genre']).shape
# Out:
# (1229, 10)

# %%
movie.drop_duplicates().shape
# Out:
# (1284, 10)

# %%
movie['directors'].value_counts()
# Out:
# PRIYADARSHAN                                                                                 18
# RAM GOPAL VARMA                                                                              17
# VIKRAM BHATT                                                                                 16
# DAVID DHAWAN                                                                                 11
# ABBAS ALIBHAI BURMAWALLA | MASTAN ALIBHAI BURMAWALLA                                         10
#                                                                                              ..
# ASHIM S. SAMANTA                                                                              1
# JASMEET DHODHI | MEGHNA GULZAR | SANJAY GUPTA | APOORVA LAKHIA | HANSAL MEHTA | ROHIT ROY     1
# JAGDISH RAJPUROHIT                                                                            1
# IMRAN KHAN                                                                                    1
# ...

# %%
movie.tail(5)
# Out:
#                          imdbId  releaseYear  releaseDate  \
# title
# Bardaasht             tt0409724         2004  23 Apr 2004
# Guzaarish             tt1438298         2010  19 Nov 2010
# Chal Chala Chal       tt1438486         2009  06 Feb 2009
# Fast Forward          tt1442570         2009  25 Sep 2009
# 26th July at Barista  tt1216276         2008  14 Mar 2008
#
#                                          genre  \
# title
# Bardaasht                                Drama
# Guzaarish             Comedy | Drama | Romance
# Chal Chala Chal        Action | Comedy | Crime
# Fast Forward          Action | Drama | Musical
# 26th July at Barista                     Drama
#
#                                                                 writers  \
# title
# Bardaasht             Vikram Bhatt (screenplay) | Vikram Bhatt (stor...
# Guzaarish             Sanjay Leela Bhansali (screenplay) | Bhavani I...
# Chal Chala Chal       Anand Raj Anand (lyrics) | Sunil Jha (lyrics) ...
# ...
